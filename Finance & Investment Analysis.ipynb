# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_excel("E:\Projects\Finance & Investment Analysis/DataSet.xlsx")
print(data)
# Out:
#     gender  age Investment_Avenues  Mutual_Funds  Equity_Market  Debentures  \
# 0   Female   34                Yes             1              2           5
# 1   Female   23                Yes             4              3           2
# 2     Male   30                Yes             3              6           4
# 3     Male   22                Yes             2              1           3
# 4   Female   24                 No             2              1           3
# 5   Female   24                 No             7              5           4
# 6   Female   27                Yes             3              6           4
# 7     Male   21                Yes             2              3           7
# 8     Male   35                Yes             2              4           7
# 9     Male   31                Yes             1              3           7
# 10  Female   35                Yes             2              4           7
# ...

# %%
data.head()
# Out:
#    gender  age Investment_Avenues  Mutual_Funds  Equity_Market  Debentures  \
# 0  Female   34                Yes             1              2           5
# 1  Female   23                Yes             4              3           2
# 2    Male   30                Yes             3              6           4
# 3    Male   22                Yes             2              1           3
# 4  Female   24                 No             2              1           3
#
#    Government_Bonds  Fixed_Deposits  PPF  Gold  ...           Duration  \
# 0                 3               7    6     4  ...          1-3 years
# 1                 1               5    6     7  ...  More than 5 years
# 2                 2               5    1     7  ...          3-5 years
# 3                 7               6    4     5  ...   Less than 1 year
# 4                 6               4    5     7  ...   Less than 1 year
#
#   Invest_Monitor   Expect       Avenue What are your savings objectives?  \
# ...

# %%
data.tail()
# Out:
#    gender  age Investment_Avenues  Mutual_Funds  Equity_Market  Debentures  \
# 35   Male   30                Yes             1              4           6
# 36   Male   30                Yes             2              4           7
# 37   Male   25                Yes             5              4           7
# 38   Male   31                Yes             2              4           7
# 39   Male   29                Yes             4              3           5
#
#     Government_Bonds  Fixed_Deposits  PPF  Gold  ...   Duration  \
# 35                 5               3    2     7  ...  3-5 years
# 36                 5               1    3     6  ...  1-3 years
# 37                 6               1    2     3  ...  3-5 years
# 38                 5               3    1     6  ...  1-3 years
# 39                 7               2    1     6  ...  3-5 years
#
#    Invest_Monitor   Expect                 Avenue  \
# 35        Monthly  20%-30%         Fixed Deposits
# ...

# %%
data.shape
# Out:
# (40, 24)

# %%
data.columns
# Out:
# Index(['gender', 'age', 'Investment_Avenues', 'Mutual_Funds', 'Equity_Market',
#        'Debentures', 'Government_Bonds', 'Fixed_Deposits', 'PPF', 'Gold',
#        'Stock_Marktet', 'Factor', 'Objective', 'Purpose', 'Duration',
#        'Invest_Monitor', 'Expect', 'Avenue',
#        'What are your savings objectives?', 'Reason_Equity', 'Reason_Mutual',
#        'Reason_Bonds', 'Reason_FD', 'Source'],
#       dtype='object')

# %%
data.dtypes
# Out:
# gender                               object
# age                                   int64
# Investment_Avenues                   object
# Mutual_Funds                          int64
# Equity_Market                         int64
# Debentures                            int64
# Government_Bonds                      int64
# Fixed_Deposits                        int64
# PPF                                   int64
# Gold                                  int64
# Stock_Marktet                        object
# Factor                               object
# Objective                            object
# Purpose                              object
# Duration                             object
# Invest_Monitor                       object
# Expect                               object
# Avenue                               object
# What are your savings objectives?    object
# Reason_Equity                        object
# Reason_Mutual                        object
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 24 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   gender                             40 non-null     object
#  1   age                                40 non-null     int64
#  2   Investment_Avenues                 40 non-null     object
#  3   Mutual_Funds                       40 non-null     int64
#  4   Equity_Market                      40 non-null     int64
#  5   Debentures                         40 non-null     int64
#  6   Government_Bonds                   40 non-null     int64
#  7   Fixed_Deposits                     40 non-null     int64
#  8   PPF                                40 non-null     int64
#  9   Gold                               40 non-null     int64
#  10  Stock_Marktet                      40 non-null     object
# ...

# %%
data.describe()
# Out:
#              age  Mutual_Funds  Equity_Market  Debentures  Government_Bonds  \
# count  40.000000     40.000000      40.000000   40.000000         40.000000
# mean   27.800000      2.550000       3.475000    5.750000          4.650000
# std     3.560467      1.197219       1.131994    1.675617          1.369072
# min    21.000000      1.000000       1.000000    1.000000          1.000000
# 25%    25.750000      2.000000       3.000000    5.000000          4.000000
# 50%    27.000000      2.000000       4.000000    6.500000          5.000000
# 75%    30.000000      3.000000       4.000000    7.000000          5.000000
# max    35.000000      7.000000       6.000000    7.000000          7.000000
#
#        Fixed_Deposits        PPF       Gold
# count       40.000000  40.000000  40.000000
# mean         3.575000   2.025000   5.975000
# std          1.795828   1.609069   1.143263
# min          1.000000   1.000000   2.000000
# 25%          2.750000   1.000000   6.000000
# ...

# %%
data.columns
# Out:
# Index(['gender', 'age', 'Investment_Avenues', 'Mutual_Funds', 'Equity_Market',
#        'Debentures', 'Government_Bonds', 'Fixed_Deposits', 'PPF', 'Gold',
#        'Stock_Marktet', 'Factor', 'Objective', 'Purpose', 'Duration',
#        'Invest_Monitor', 'Expect', 'Avenue',
#        'What are your savings objectives?', 'Reason_Equity', 'Reason_Mutual',
#        'Reason_Bonds', 'Reason_FD', 'Source'],
#       dtype='object')

# %%
data['Stock_Marktet'] = data['Stock_Marktet'].replace({'Yes':1,'No':0})

# %%
data['Stock_Marktet']
# Out:
# 0     Yes
# 1      No
# 2     Yes
# 3     Yes
# 4      No
# 5      No
# 6     Yes
# 7     Yes
# 8     Yes
# 9     Yes
# 10    Yes
# 11    Yes
# 12     No
# 13    Yes
# 14    Yes
# 15    Yes
# 16    Yes
# 17    Yes
# 18    Yes
# 19    Yes
# 20    Yes
# 21    Yes
# 22    Yes
# 23    Yes
# 24    Yes
# 25    Yes
# 26    Yes
# 27    Yes
# 28    Yes
# 29    Yes
# 30     No
# 31    Yes
# 32    Yes
# 33    Yes
# 34    Yes
# 35    Yes
# 36    Yes
# 37    Yes
# 38    Yes
# 39    Yes
# Name: Stock_Marktet, dtype: object

# %%
data.isnull().sum()
# Out:
# gender                               0
# age                                  0
# Investment_Avenues                   0
# Mutual_Funds                         0
# Equity_Market                        0
# Debentures                           0
# Government_Bonds                     0
# Fixed_Deposits                       0
# PPF                                  0
# Gold                                 0
# Stock_Marktet                        0
# Factor                               0
# Objective                            0
# Purpose                              0
# Duration                             0
# Invest_Monitor                       0
# Expect                               0
# Avenue                               0
# What are your savings objectives?    0
# Reason_Equity                        0
# Reason_Mutual                        0
# Reason_Bonds                         0
# Reason_FD                            0
# Source                               0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
data.nunique()
# Out:
# gender                                2
# age                                  14
# Investment_Avenues                    2
# Mutual_Funds                          6
# Equity_Market                         6
# Debentures                            7
# Government_Bonds                      7
# Fixed_Deposits                        7
# PPF                                   6
# Gold                                  6
# Stock_Marktet                         2
# Factor                                3
# Objective                             3
# Purpose                               3
# Duration                              4
# Invest_Monitor                        3
# Expect                                3
# Avenue                                4
# What are your savings objectives?     3
# Reason_Equity                         3
# Reason_Mutual                         3
# Reason_Bonds                          3
# Reason_FD                             3
# ...

# %%
data['Investment_Avenues'].value_counts().plot(kind='bar')
plt.title('Overall Investment Preference')
plt.xlabel('Investment Avenue')
plt.ylabel('Number of Respondents')
plt.show()

# %%
data['Stock_Marktet'].value_counts().plot(kind='bar')
plt.title('Stock Market Participation')
plt.xlabel('Stock Market (1 = Yes,0 = No)')
plt.ylabel('Count')
plt.show()

# %%
pd.crosstab(data['gender'], data['Investment_Avenues']).plot(
    kind='bar', stacked=True
)
plt.title('Gender vs Investment Avenue')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()

# %%
data.columns
# Out:
# Index(['gender', 'age', 'Investment_Avenues', 'Mutual_Funds', 'Equity_Market',
#        'Debentures', 'Government_Bonds', 'Fixed_Deposits', 'PPF', 'Gold',
#        'Stock_Marktet', 'Factor', 'Objective', 'Purpose', 'Duration',
#        'Invest_Monitor', 'Expect', 'Avenue',
#        'What are your savings objectives?', 'Reason_Equity', 'Reason_Mutual',
#        'Reason_Bonds', 'Reason_FD', 'Source'],
#       dtype='object')

# %%
bins = [20, 25, 30, 35]
labels = ['20-25', '26-30', '31-35']

data['Age_Group'] = pd.cut(
    data['age'],
    bins=bins,
    labels=labels,
    include_lowest=True,
    right=True
)

# %%
data.columns
# Out:
# Index(['gender', 'age', 'Investment_Avenues', 'Mutual_Funds', 'Equity_Market',
#        'Debentures', 'Government_Bonds', 'Fixed_Deposits', 'PPF', 'Gold',
#        'Stock_Marktet', 'Factor', 'Objective', 'Purpose', 'Duration',
#        'Invest_Monitor', 'Expect', 'Avenue',
#        'What are your savings objectives?', 'Reason_Equity', 'Reason_Mutual',
#        'Reason_Bonds', 'Reason_FD', 'Source', 'Age_Group'],
#       dtype='object')

# %%
data.head(5)
# Out:
#    gender  age Investment_Avenues  Mutual_Funds  Equity_Market  Debentures  \
# 0  Female   34                Yes             1              2           5
# 1  Female   23                Yes             4              3           2
# 2    Male   30                Yes             3              6           4
# 3    Male   22                Yes             2              1           3
# 4  Female   24                 No             2              1           3
#
#    Government_Bonds  Fixed_Deposits  PPF  Gold  ...  Invest_Monitor   Expect  \
# 0                 3               7    6     4  ...         Monthly  20%-30%
# 1                 1               5    6     7  ...          Weekly  20%-30%
# 2                 2               5    1     7  ...           Daily  20%-30%
# 3                 7               6    4     5  ...           Daily  10%-20%
# 4                 6               4    5     7  ...           Daily  20%-30%
#
# ...

# %%
data[['age', 'Age_Group']].head()
# Out:
#    age Age_Group
# 0   34     31-35
# 1   23     20-25
# 2   30     26-30
# 3   22     20-25
# 4   24     20-25

# %%
pd.crosstab(data['Age_Group'], data['Factor']).plot(
    kind='bar', stacked=False
)
# Out:
# <Axes: xlabel='Age_Group'>

# %%
data.columns
# Out:
# Index(['gender', 'age', 'Investment_Avenues', 'Mutual_Funds', 'Equity_Market',
#        'Debentures', 'Government_Bonds', 'Fixed_Deposits', 'PPF', 'Gold',
#        'Stock_Marktet', 'Factor', 'Objective', 'Purpose', 'Duration',
#        'Invest_Monitor', 'Expect', 'Avenue',
#        'What are your savings objectives?', 'Reason_Equity', 'Reason_Mutual',
#        'Reason_Bonds', 'Reason_FD', 'Source', 'Age_Group'],
#       dtype='object')

# %%
plt.figure(figsize=(10,4))
sns.countplot(
    data=data,
    x='Factor',
    hue='gender'
)
plt.title('Investment Factor vs Gender')
plt.show()

# %%
plt.figure(figsize=(10,4))
sns.countplot(
    data=data,
    x='Objective',
    hue='gender'
)
plt.title('Objective vs Gender')
plt.show()

# %%
data.columns
# Out:
# Index(['gender', 'age', 'Investment_Avenues', 'Mutual_Funds', 'Equity_Market',
#        'Debentures', 'Government_Bonds', 'Fixed_Deposits', 'PPF', 'Gold',
#        'Stock_Marktet', 'Factor', 'Objective', 'Purpose', 'Duration',
#        'Invest_Monitor', 'Expect', 'Avenue',
#        'What are your savings objectives?', 'Reason_Equity', 'Reason_Mutual',
#        'Reason_Bonds', 'Reason_FD', 'Source', 'Age_Group'],
#       dtype='object')

# %%
plt.figure(figsize=(10,4))
sns.countplot(
    data=data,
    x='Purpose',
    hue='gender'
)
plt.title('Purpose vs Gender')
plt.show()

# %%
plt.figure(figsize=(10,4))
sns.countplot(
    data=data,
    x='Duration',
    hue='gender'
)
plt.title('Duration vs Gender')
plt.show()

# %%
plt.figure(figsize=(10,4))
sns.countplot(
    data=data,
    x='Invest_Monitor',
    hue='gender'
)
plt.title('Invest_Monitor vs Gender')
plt.show()

# %%
plt.figure(figsize=(10,4))
sns.countplot(
    data=data,
    x='Avenue',
    hue='gender'
)
plt.title('Avenue vs Gender')
plt.show()

# %%
data.columns
# Out:
# Index(['gender', 'age', 'Investment_Avenues', 'Mutual_Funds', 'Equity_Market',
#        'Debentures', 'Government_Bonds', 'Fixed_Deposits', 'PPF', 'Gold',
#        'Stock_Marktet', 'Factor', 'Objective', 'Purpose', 'Duration',
#        'Invest_Monitor', 'Expect', 'Avenue',
#        'What are your savings objectives?', 'Reason_Equity', 'Reason_Mutual',
#        'Reason_Bonds', 'Reason_FD', 'Source', 'Age_Group'],
#       dtype='object')

# %%
plt.figure(figsize=(10,4))
sns.countplot(
    data=data,
    x='What are your savings objectives?',
    hue='gender'
)
plt.title('What are your savings objectives? vs Gender')
plt.show()

# %%
plt.figure(figsize=(10,4))
sns.countplot(
    data=data,
    x='Reason_Equity',
    hue='gender'
)
plt.title('Reason_Equity vs Gender')
plt.show()

# %%
plt.figure(figsize=(10,4))
sns.countplot(
    data=data,
    x='Reason_Mutual',
    hue='gender'
)
plt.title('Reason_Mutual vs Gender')
plt.show()

# %%
plt.figure(figsize=(10,4))
sns.countplot(
    data=data,
    x='Reason_Bonds',
    hue='gender'
)
plt.title('Reason_Bouds vs Gender')
plt.show()

# %%
plt.figure(figsize=(10,4))
sns.countplot(
    data=data,
    x='Reason_FD',
    hue='gender'
)
plt.title('Reason_FD vs Gender')
plt.show()

# %%
plt.figure(figsize=(10,4))
sns.countplot(
    data=data,
    x='Source',
    hue='gender'
)
plt.title('Source vs Gender')
plt.show()

# %%
data.columns
# Out:
# Index(['gender', 'age', 'Investment_Avenues', 'Mutual_Funds', 'Equity_Market',
#        'Debentures', 'Government_Bonds', 'Fixed_Deposits', 'PPF', 'Gold',
#        'Stock_Marktet', 'Factor', 'Objective', 'Purpose', 'Duration',
#        'Invest_Monitor', 'Expect', 'Avenue',
#        'What are your savings objectives?', 'Reason_Equity', 'Reason_Mutual',
#        'Reason_Bonds', 'Reason_FD', 'Source', 'Age_Group'],
#       dtype='object')

# %%
for i , predictor in enumerate(data.drop(columns=['gender','age','Mutual_Funds','Equity_Market','Equity_Market','Debentures','Government_Bonds','Fixed_Deposits','PPF','Gold','Stock_Marktet'],)):
    plt.figure(i)
    plt.figure(figsize=(10, 6))
    sns.countplot(data,x =predictor ,hue='gender' , )

# %%
data.columns
# Out:
# Index(['gender', 'age', 'Investment_Avenues', 'Mutual_Funds', 'Equity_Market',
#        'Debentures', 'Government_Bonds', 'Fixed_Deposits', 'PPF', 'Gold',
#        'Stock_Marktet', 'Factor', 'Objective', 'Purpose', 'Duration',
#        'Invest_Monitor', 'Expect', 'Avenue',
#        'What are your savings objectives?', 'Reason_Equity', 'Reason_Mutual',
#        'Reason_Bonds', 'Reason_FD', 'Source', 'Age_Group'],
#       dtype='object')

# %%
for i , predictor in enumerate(data.drop(columns=['gender','age','Mutual_Funds','Equity_Market','Equity_Market','Debentures','Government_Bonds','Fixed_Deposits','PPF','Gold','Stock_Marktet'],)):
    plt.figure(i)
    plt.figure(figsize=(10, 6))
    sns.countplot(data,x =predictor ,hue='Age_Group' , )

# %%
data.columns
# Out:
# Index(['gender', 'age', 'Investment_Avenues', 'Mutual_Funds', 'Equity_Market',
#        'Debentures', 'Government_Bonds', 'Fixed_Deposits', 'PPF', 'Gold',
#        'Stock_Marktet', 'Factor', 'Objective', 'Purpose', 'Duration',
#        'Invest_Monitor', 'Expect', 'Avenue',
#        'What are your savings objectives?', 'Reason_Equity', 'Reason_Mutual',
#        'Reason_Bonds', 'Reason_FD', 'Source', 'Age_Group'],
#       dtype='object')

# %%
data['Objective'].value_counts().plot(kind = 'bar')
plt.xlabel = 'Objectives'
plt.ylabel= 'Counts'
plt.title = 'Total Counts of Objectives'
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
data['Purpose'].value_counts().plot(kind = 'bar')
plt.xlabel = 'Purpose'
plt.ylabel= 'Counts'
plt.title = 'Total Counts of Purose'
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
data['Duration'].value_counts().plot(kind = 'bar')
plt.xlabel = 'Duration'
plt.ylabel= 'Counts'
plt.title = 'Total Counts of Duration'
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
data.columns
# Out:
# Index(['gender', 'age', 'Investment_Avenues', 'Mutual_Funds', 'Equity_Market',
#        'Debentures', 'Government_Bonds', 'Fixed_Deposits', 'PPF', 'Gold',
#        'Stock_Marktet', 'Factor', 'Objective', 'Purpose', 'Duration',
#        'Invest_Monitor', 'Expect', 'Avenue',
#        'What are your savings objectives?', 'Reason_Equity', 'Reason_Mutual',
#        'Reason_Bonds', 'Reason_FD', 'Source', 'Age_Group'],
#       dtype='object')

# %%
data['Avenue'].value_counts().plot(kind = 'pie')
plt.xlabel = 'Avenue'
plt.ylabel= 'Counts'
plt.title = 'Total Counts of Avenue'
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
data['What are your savings objectives?'].value_counts().plot(kind = 'bar')
plt.xlabel = 'What are your savings objectives?'
plt.ylabel= 'Counts'
plt.title = 'Total Counts of savings objectives'
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
data['Reason_Equity'].value_counts().plot(kind = 'bar')
plt.xlabel = 'Reason_Equity'
plt.ylabel= 'Counts'
plt.title = 'Total Counts of Reason_Equity'
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
data['Reason_Mutual'].value_counts().plot(kind = 'bar')
plt.xlabel = 'Reason_Mutual'
plt.ylabel= 'Counts'
plt.title = 'Total Counts of Reason_Mutual'
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
data['Reason_Bonds'].value_counts().plot(kind = 'bar')
plt.xlabel = 'Reason_Bonds'
plt.ylabel= 'Counts'
plt.title = 'Total Counts of Reason_Bonds'
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
data['Reason_FD'].value_counts().plot(kind = 'bar')
plt.xlabel = 'Reason_FD'
plt.ylabel= 'Counts'
plt.title = 'Total Counts of Reason_FD'
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
data['Source'].value_counts().plot(kind = 'bar',figsize=(8,6))
plt.xlabel = 'Source'
plt.ylabel= 'Counts'
plt.title = 'Total Counts of Source'
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()
